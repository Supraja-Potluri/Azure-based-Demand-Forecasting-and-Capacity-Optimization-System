# %% [markdown]
# # **Milestone** 1

# %%
import pandas as pd
import numpy as np

# %%
# 1. LOAD RAW DATA
df = pd.read_csv("azure_demand_raw.csv")

print("Initial shape:", df.shape)
print(df.head())
# Out:
# Initial shape: (5700, 10)
#              timestamp        region service_type  usage_units  \
# 0  2023-03-12 01:14:50       us-west      Storage      8824.65
# 1  2023-01-31 10:18:59  Europe-North      Compute     13098.88
# 2  2023-08-30 21:38:21       us-east      Storage          NaN
# 3  2024-02-19 05:23:30       us east      Storage      6408.14
# 4  2024-03-19 21:40:00       us-west      Compute     11940.33
#
#    provisioned_capacity  cost_usd  availability_pct  cloud_spend_index  \
# 0                  8000   2823.89             99.94              92.91
# 1                 10000   6287.46             99.69             103.90
# 2                  8000       NaN             99.57              90.63
# 3                  8000   2050.61             99.46             100.01
# 4                 10000   5731.36             99.89              96.41
#
#    enterprise_demand_index  new_service_launch
# 0                     1.21                   0
# 1                     1.35                   0
# 2                     1.02                   0
# 3                     0.79                   0
# 4                     1.08                   0

# %%
# 2. FIX TIMESTAMP
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
df = df.dropna(subset=['timestamp'])
df = df.sort_values('timestamp')

# %%
# 3. REMOVE DUPLICATES
df = df.drop_duplicates()
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (5500, 10)

# %%
# 4. STANDARDIZE REGION NAMES
df['region'] = (
    df['region']
    .str.strip()
    .str.lower()
    .str.replace(" ", "-", regex=False)
)

df['region'] = df['region'].replace({
    'us-east': 'US-East',
    'us-west': 'US-West',
    'india-south': 'India-South',
    'europe-north': 'Europe-North'
})

# %%
# 5. STANDARDIZE SERVICE TYPE
df['service_type'] = df['service_type'].str.title()

# %%
# 6. HANDLE MISSING VALUES

# Time-series interpolation for usage
df['usage_units'] = df['usage_units'].interpolate(method='linear')

# Cost recompute if missing
df['cost_usd'] = df['cost_usd'].fillna(df['usage_units'] * 0.45)

# Availability forward fill
df['availability_pct'] = df['availability_pct'].ffill()

# Economic variables --> median
df['cloud_spend_index'] = df['cloud_spend_index'].fillna(
    df['cloud_spend_index'].median()
)

df['enterprise_demand_index'] = df['enterprise_demand_index'].fillna(
    df['enterprise_demand_index'].median()
)

# Technical binary variable
df['new_service_launch'] = df['new_service_launch'].fillna(0)

# %%
# 7. VALIDATION RULES

# Remove unrealistic usage
df = df[df['usage_units'] > 0]

# Availability must be realistic
df = df[(df['availability_pct'] >= 95) & (df['availability_pct'] <= 100)]

# Remove negative costs
df = df[df['cost_usd'] > 0]

print("\nRemaining NaNs:\n", df.isnull().sum())
print("Final shape after cleaning:", df.shape)
# Out:
# Remaining NaNs:
#  timestamp                  0
# region                     0
# service_type               0
# usage_units                0
# provisioned_capacity       0
# cost_usd                   0
# availability_pct           0
# cloud_spend_index          0
# enterprise_demand_index    0
# new_service_launch         0
# dtype: int64
# Final shape after cleaning: (5500, 10)

# %%
# 8. SAVE CLEAN DATA
df.to_csv("azure_demand_cleaned.csv", index=False)

print("Clean dataset saved successfully.")
# Out:
# Clean dataset saved successfully.

# %% [markdown]
# # **Milestone 2**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("azure_demand_cleaned.csv")

df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (5500, 10)
#             timestamp        region service_type  usage_units  \
# 0 2023-01-01 00:54:15  Europe-North      Compute     11070.03
# 1 2023-01-01 03:41:33   India-South      Compute     10606.77
# 2 2023-01-01 08:32:08       US-East      Storage      8647.21
# 3 2023-01-01 10:45:17   India-South      Compute     14125.23
# 4 2023-01-01 12:25:13       US-East      Compute     10985.42
#
#    provisioned_capacity  cost_usd  availability_pct  cloud_spend_index  \
# 0                 10000   5313.61             99.60             110.15
# 1                 10000   5091.25             99.84              98.46
# 2                  8000   2767.11             99.57             108.16
# 3                 10000   6780.11             99.91             128.31
# 4                 10000   5273.00             99.80             102.13
#
#    enterprise_demand_index  new_service_launch
# 0                     1.14                   0
# 1                     1.24                   0
# 2                     1.07                   1
# 3                     1.24                   0
# 4                     1.27                   0

# %%
df['hour'] = df['timestamp'].dt.hour
df['day'] = df['timestamp'].dt.day
df['day_of_week'] = df['timestamp'].dt.dayofweek
df['month'] = df['timestamp'].dt.month
df['week_of_year'] = df['timestamp'].dt.isocalendar().week.astype(int)
print(df)
# Out:
#                timestamp        region service_type  usage_units  \
# 0    2023-01-01 00:54:15  Europe-North      Compute     11070.03
# 1    2023-01-01 03:41:33   India-South      Compute     10606.77
# 2    2023-01-01 08:32:08       US-East      Storage      8647.21
# 3    2023-01-01 10:45:17   India-South      Compute     14125.23
# 4    2023-01-01 12:25:13       US-East      Compute     10985.42
# ...                  ...           ...          ...          ...
# 5495 2024-03-30 12:42:31       US-East      Compute      9205.24
# 5496 2024-03-30 14:43:55   India-South      Storage     13582.78
# 5497 2024-03-30 18:25:09   India-South      Compute     14645.86
# 5498 2024-03-30 19:54:04       US-West      Storage     12837.44
# 5499 2024-03-30 23:57:13       US-West      Compute     12670.51
#
#       provisioned_capacity   cost_usd  availability_pct  cloud_spend_index  \
# 0                    10000  5313.6100             99.60             110.15
# 1                    10000  5091.2500             99.84              98.46
# 2                     8000  2767.1100             99.57             108.16
# 3                    10000  6780.1100             99.91             128.31
# 4                    10000  5273.0000             99.80             102.13
# ...                    ...        ...               ...                ...
# 5495                 10000  4418.5200             99.87             109.11
# 5496                  8000  4346.4900             99.69             119.01
# 5497                 10000  7030.0100             99.76              97.25
# 5498                  8000  4107.9800             99.32             115.32
# 5499                 10000  5701.7295             99.69             121.03
#
#       enterprise_demand_index  new_service_launch  hour  day  day_of_week  \
# 0                        1.14                   0     0    1            6
# 1                        1.24                   0     3    1            6
# 2                        1.07                   1     8    1            6
# 3                        1.24                   0    10    1            6
# 4                        1.27                   0    12    1            6
# ...                       ...                 ...   ...  ...          ...
# 5495                     0.75                   0    12   30            5
# 5496                     1.35                   0    14   30            5
# 5497                     1.35                   0    18   30            5
# 5498                     1.23                   1    19   30            5
# 5499                     0.92                   0    23   30            5
#
#       month  week_of_year
# 0         1            52
# 1         1            52
# 2         1            52
# 3         1            52
# 4         1            52
# ...     ...           ...
# 5495      3            13
# 5496      3            13
# 5497      3            13
# 5498      3            13
# 5499      3            13
#
# [5500 rows x 15 columns]

# %%
df['lag_1_usage'] = df['usage_units'].shift(1)
df['lag_7_usage'] = df['usage_units'].shift(7)
df['lag_14_usage'] = df['usage_units'].shift(14)
print(df)
# Out:
#                timestamp        region service_type  usage_units  \
# 0    2023-01-01 00:54:15  Europe-North      Compute     11070.03
# 1    2023-01-01 03:41:33   India-South      Compute     10606.77
# 2    2023-01-01 08:32:08       US-East      Storage      8647.21
# 3    2023-01-01 10:45:17   India-South      Compute     14125.23
# 4    2023-01-01 12:25:13       US-East      Compute     10985.42
# ...                  ...           ...          ...          ...
# 5495 2024-03-30 12:42:31       US-East      Compute      9205.24
# 5496 2024-03-30 14:43:55   India-South      Storage     13582.78
# 5497 2024-03-30 18:25:09   India-South      Compute     14645.86
# 5498 2024-03-30 19:54:04       US-West      Storage     12837.44
# 5499 2024-03-30 23:57:13       US-West      Compute     12670.51
#
#       provisioned_capacity   cost_usd  availability_pct  cloud_spend_index  \
# 0                    10000  5313.6100             99.60             110.15
# 1                    10000  5091.2500             99.84              98.46
# 2                     8000  2767.1100             99.57             108.16
# 3                    10000  6780.1100             99.91             128.31
# 4                    10000  5273.0000             99.80             102.13
# ...                    ...        ...               ...                ...
# 5495                 10000  4418.5200             99.87             109.11
# 5496                  8000  4346.4900             99.69             119.01
# 5497                 10000  7030.0100             99.76              97.25
# 5498                  8000  4107.9800             99.32             115.32
# 5499                 10000  5701.7295             99.69             121.03
#
#       enterprise_demand_index  new_service_launch  hour  day  day_of_week  \
# 0                        1.14                   0     0    1            6
# 1                        1.24                   0     3    1            6
# 2                        1.07                   1     8    1            6
# 3                        1.24                   0    10    1            6
# 4                        1.27                   0    12    1            6
# ...                       ...                 ...   ...  ...          ...
# 5495                     0.75                   0    12   30            5
# 5496                     1.35                   0    14   30            5
# 5497                     1.35                   0    18   30            5
# 5498                     1.23                   1    19   30            5
# 5499                     0.92                   0    23   30            5
#
#       month  week_of_year  lag_1_usage  lag_7_usage  lag_14_usage
# 0         1            52          NaN          NaN           NaN
# 1         1            52     11070.03          NaN           NaN
# 2         1            52     10606.77          NaN           NaN
# 3         1            52      8647.21          NaN           NaN
# 4         1            52     14125.23          NaN           NaN
# ...     ...           ...          ...          ...           ...
# 5495      3            13      7664.58      8516.89      9490.150
# 5496      3            13      9205.24     11523.77      7693.460
# 5497      3            13     13582.78     13715.42     10603.365
# 5498      3            13     14645.86      9061.51     13513.270
# 5499      3            13     12837.44      7802.78     12156.120
#
# [5500 rows x 18 columns]

# %%
df['rolling_mean_3'] = df['usage_units'].rolling(window=3).mean()
df['rolling_mean_7'] = df['usage_units'].rolling(window=7).mean()

df['rolling_std_7'] = df['usage_units'].rolling(window=7).std()
print(df)
# Out:
#                timestamp        region service_type  usage_units  \
# 0    2023-01-01 00:54:15  Europe-North      Compute     11070.03
# 1    2023-01-01 03:41:33   India-South      Compute     10606.77
# 2    2023-01-01 08:32:08       US-East      Storage      8647.21
# 3    2023-01-01 10:45:17   India-South      Compute     14125.23
# 4    2023-01-01 12:25:13       US-East      Compute     10985.42
# ...                  ...           ...          ...          ...
# 5495 2024-03-30 12:42:31       US-East      Compute      9205.24
# 5496 2024-03-30 14:43:55   India-South      Storage     13582.78
# 5497 2024-03-30 18:25:09   India-South      Compute     14645.86
# 5498 2024-03-30 19:54:04       US-West      Storage     12837.44
# 5499 2024-03-30 23:57:13       US-West      Compute     12670.51
#
#       provisioned_capacity   cost_usd  availability_pct  cloud_spend_index  \
# 0                    10000  5313.6100             99.60             110.15
# 1                    10000  5091.2500             99.84              98.46
# 2                     8000  2767.1100             99.57             108.16
# 3                    10000  6780.1100             99.91             128.31
# 4                    10000  5273.0000             99.80             102.13
# ...                    ...        ...               ...                ...
# 5495                 10000  4418.5200             99.87             109.11
# 5496                  8000  4346.4900             99.69             119.01
# 5497                 10000  7030.0100             99.76              97.25
# 5498                  8000  4107.9800             99.32             115.32
# 5499                 10000  5701.7295             99.69             121.03
#
#       enterprise_demand_index  new_service_launch  ...  day  day_of_week  \
# 0                        1.14                   0  ...    1            6
# 1                        1.24                   0  ...    1            6
# 2                        1.07                   1  ...    1            6
# 3                        1.24                   0  ...    1            6
# 4                        1.27                   0  ...    1            6
# ...                       ...                 ...  ...  ...          ...
# 5495                     0.75                   0  ...   30            5
# 5496                     1.35                   0  ...   30            5
# 5497                     1.35                   0  ...   30            5
# 5498                     1.23                   1  ...   30            5
# 5499                     0.92                   0  ...   30            5
#
#       month  week_of_year  lag_1_usage  lag_7_usage  lag_14_usage  \
# 0         1            52          NaN          NaN           NaN
# 1         1            52     11070.03          NaN           NaN
# 2         1            52     10606.77          NaN           NaN
# 3         1            52      8647.21          NaN           NaN
# 4         1            52     14125.23          NaN           NaN
# ...     ...           ...          ...          ...           ...
# 5495      3            13      7664.58      8516.89      9490.150
# 5496      3            13      9205.24     11523.77      7693.460
# 5497      3            13     13582.78     13715.42     10603.365
# 5498      3            13     14645.86      9061.51     13513.270
# 5499      3            13     12837.44      7802.78     12156.120
#
#       rolling_mean_3  rolling_mean_7  rolling_std_7
# 0                NaN             NaN            NaN
# 1                NaN             NaN            NaN
# 2       10108.003333             NaN            NaN
# 3       11126.403333             NaN            NaN
# 4       11252.620000             NaN            NaN
# ...              ...             ...            ...
# 5495     9725.466667    10182.840000    2345.452624
# 5496    10150.866667    10476.984286    2650.872208
# 5497    12477.960000    10609.904286    2855.728907
# 5498    13688.693333    11149.322857    2871.083108
# 5499    13384.603333    11844.712857    2489.591658
#
# [5500 rows x 21 columns]

# %%
threshold = df['usage_units'].mean() + df['usage_units'].std()
df['demand_spike'] = (df['usage_units'] > threshold).astype(int)
print(df)
# Out:
#                timestamp        region service_type  usage_units  \
# 0    2023-01-01 00:54:15  Europe-North      Compute     11070.03
# 1    2023-01-01 03:41:33   India-South      Compute     10606.77
# 2    2023-01-01 08:32:08       US-East      Storage      8647.21
# 3    2023-01-01 10:45:17   India-South      Compute     14125.23
# 4    2023-01-01 12:25:13       US-East      Compute     10985.42
# ...                  ...           ...          ...          ...
# 5495 2024-03-30 12:42:31       US-East      Compute      9205.24
# 5496 2024-03-30 14:43:55   India-South      Storage     13582.78
# 5497 2024-03-30 18:25:09   India-South      Compute     14645.86
# 5498 2024-03-30 19:54:04       US-West      Storage     12837.44
# 5499 2024-03-30 23:57:13       US-West      Compute     12670.51
#
#       provisioned_capacity   cost_usd  availability_pct  cloud_spend_index  \
# 0                    10000  5313.6100             99.60             110.15
# 1                    10000  5091.2500             99.84              98.46
# 2                     8000  2767.1100             99.57             108.16
# 3                    10000  6780.1100             99.91             128.31
# 4                    10000  5273.0000             99.80             102.13
# ...                    ...        ...               ...                ...
# 5495                 10000  4418.5200             99.87             109.11
# 5496                  8000  4346.4900             99.69             119.01
# 5497                 10000  7030.0100             99.76              97.25
# 5498                  8000  4107.9800             99.32             115.32
# 5499                 10000  5701.7295             99.69             121.03
#
#       enterprise_demand_index  new_service_launch  ...  day_of_week  month  \
# 0                        1.14                   0  ...            6      1
# 1                        1.24                   0  ...            6      1
# 2                        1.07                   1  ...            6      1
# 3                        1.24                   0  ...            6      1
# 4                        1.27                   0  ...            6      1
# ...                       ...                 ...  ...          ...    ...
# 5495                     0.75                   0  ...            5      3
# 5496                     1.35                   0  ...            5      3
# 5497                     1.35                   0  ...            5      3
# 5498                     1.23                   1  ...            5      3
# 5499                     0.92                   0  ...            5      3
#
#       week_of_year  lag_1_usage  lag_7_usage  lag_14_usage  rolling_mean_3  \
# 0               52          NaN          NaN           NaN             NaN
# 1               52     11070.03          NaN           NaN             NaN
# 2               52     10606.77          NaN           NaN    10108.003333
# 3               52      8647.21          NaN           NaN    11126.403333
# 4               52     14125.23          NaN           NaN    11252.620000
# ...            ...          ...          ...           ...             ...
# 5495            13      7664.58      8516.89      9490.150     9725.466667
# 5496            13      9205.24     11523.77      7693.460    10150.866667
# 5497            13     13582.78     13715.42     10603.365    12477.960000
# 5498            13     14645.86      9061.51     13513.270    13688.693333
# 5499            13     12837.44      7802.78     12156.120    13384.603333
#
#       rolling_mean_7  rolling_std_7  demand_spike
# 0                NaN            NaN             0
# 1                NaN            NaN             0
# 2                NaN            NaN             0
# 3                NaN            NaN             1
# 4                NaN            NaN             0
# ...              ...            ...           ...
# 5495    10182.840000    2345.452624             0
# 5496    10476.984286    2650.872208             1
# 5497    10609.904286    2855.728907             1
# 5498    11149.322857    2871.083108             1
# 5499    11844.712857    2489.591658             1
#
# [5500 rows x 22 columns]

# %%
df = pd.get_dummies(df, columns=['region'], drop_first=True)

# %%
df['service_type'] = df['service_type'].map({
    'Compute': 1,
    'Storage': 0
})

# %%
df = df.dropna().reset_index(drop=True)
print("After lag/rolling cleanup:", df.shape)
# Out:
# After lag/rolling cleanup: (5486, 24)

# %%
features = [
    'usage_units',
    'provisioned_capacity',
    'cost_usd',
    'availability_pct',
    'cloud_spend_index',
    'enterprise_demand_index',
    'new_service_launch',
    'hour', 'day', 'day_of_week', 'month', 'week_of_year',
    'lag_1_usage', 'lag_7_usage', 'lag_14_usage',
    'rolling_mean_3', 'rolling_mean_7', 'rolling_std_7',
    'demand_spike'
]

target = 'usage_units'

# %%
df.to_csv("azure_demand_feature_engineered.csv", index=False)
print("Milestone-2 dataset saved successfully")
# Out:
# Milestone-2 dataset saved successfully

# %% [markdown]
# # **Milestone 3**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("azure_demand_feature_engineered.csv")

df["timestamp"] = pd.to_datetime(df["timestamp"])

df = df.sort_values("timestamp").reset_index(drop=True)

df.head()
# Out:
#             timestamp  service_type  usage_units  provisioned_capacity  \
# 0 2023-01-02 05:19:30             1      7269.32                 10000
# 1 2023-01-02 06:22:43             0     10429.23                  8000
# 2 2023-01-02 07:51:21             1     10260.58                 10000
# 3 2023-01-02 09:35:47             1      6776.61                 10000
# 4 2023-01-02 10:57:45             0     11442.92                  8000
#
#    cost_usd  availability_pct  cloud_spend_index  enterprise_demand_index  \
# 0   3489.27             99.60             104.03                     0.88
# 1   3337.35             99.95             125.06                     1.24
# 2   4925.08             99.63             104.13                     1.03
# 3   3252.77             99.53              91.35                     0.83
# 4   3661.74             99.85             129.24                     1.05
#
#    new_service_launch  hour  ...  lag_1_usage  lag_7_usage  lag_14_usage  \
# 0                   0     5  ...      7571.60      6568.69      11070.03
# 1                   0     6  ...      7269.32      8632.58      10606.77
# 2                   1     7  ...     10429.23      7188.33       8647.21
# 3                   0     9  ...     10260.58      9614.94      14125.23
# 4                   0    10  ...      6776.61     14350.29      10985.42
#
#    rolling_mean_3  rolling_mean_7  rolling_std_7  demand_spike  \
# 0     7996.660000     9110.874286    2496.418998             0
# 1     8423.383333     9367.538571    2531.165982             0
# 2     9319.710000     9806.431429    2350.212465             0
# 3     9155.473333     9400.955714    2618.309468             0
# 4     9493.370000     8985.617143    1807.366048             0
#
#    region_India-South  region_US-East  region_US-West
# 0               False           False            True
# 1               False           False           False
# 2               False           False            True
# 3               False           False           False
# 4               False            True           False
#
# [5 rows x 24 columns]

# %%
target = "usage_units"

features = df.drop(columns=["timestamp","usage_units"]).columns

X = df[features]
y = df[target]

# %%
split = int(len(df)*0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

# %%
rf = RandomForestRegressor(random_state=42)

rf_params = {

"n_estimators":[200,300,400,500],

"max_depth":[10,15,20,None],

"min_samples_split":[2,5,10],

"min_samples_leaf":[1,2,4]

}

rf_search = RandomizedSearchCV(

rf,
rf_params,
n_iter=15,
cv=3,
scoring="neg_mean_absolute_error",
n_jobs=-1,
random_state=42

)

rf_search.fit(X_train,y_train)

best_rf = rf_search.best_estimator_

rf_pred = best_rf.predict(X_test)

print("Best RF Parameters:",rf_search.best_params_)
# Out:
# Best RF Parameters: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 15}

# %%
xgb = XGBRegressor(random_state=42)

xgb_params = {

"n_estimators":[300,400,500,600],

"max_depth":[4,6,8],

"learning_rate":[0.01,0.03,0.05,0.1],

"subsample":[0.7,0.8,0.9,1],

"colsample_bytree":[0.7,0.8,0.9,1]

}

xgb_search = RandomizedSearchCV(

xgb,
xgb_params,
n_iter=15,
cv=3,
scoring="neg_mean_absolute_error",
n_jobs=-1,
random_state=42

)

xgb_search.fit(X_train,y_train)

best_xgb = xgb_search.best_estimator_

xgb_pred = best_xgb.predict(X_test)

print("Best XGB Parameters:",xgb_search.best_params_)
# Out:
# Best XGB Parameters: {'subsample': 1, 'n_estimators': 500, 'max_depth': 8, 'learning_rate': 0.03, 'colsample_bytree': 1}

# %%
def evaluate(y_true,y_pred):

    mae = mean_absolute_error(y_true,y_pred)

    rmse = np.sqrt(mean_squared_error(y_true,y_pred))

    bias = np.mean(y_pred-y_true)

    return mae,rmse,bias

# %%
rf_mae,rf_rmse,rf_bias = evaluate(y_test,rf_pred)
xgb_mae,xgb_rmse,xgb_bias = evaluate(y_test,xgb_pred)

# %%
results = pd.DataFrame({

"Model":["Random Forest","XGBoost"],

"MAE":[rf_mae,xgb_mae],

"RMSE":[rf_rmse,xgb_rmse],

"Forecast Bias":[rf_bias,xgb_bias]

})

results.sort_values("RMSE")
# Out:
#            Model         MAE        RMSE  Forecast Bias
# 0  Random Forest  182.283003  464.448815       7.964612
# 1        XGBoost  236.318070  542.598074       1.159007

# %%
plt.figure(figsize=(12,6))

plt.plot(y_test.values,label="Actual")

plt.plot(rf_pred,label="Random Forest")

plt.plot(xgb_pred,label="XGBoost")

plt.title("Demand Forecast vs Actual")

plt.xlabel("Time")

plt.ylabel("Usage Units")

plt.legend()

plt.grid(True)

plt.show()

# %%
best_model = results.sort_values("RMSE").iloc[0]["Model"]
print("Best Model:",best_model)
# Out:
# Best Model: Random Forest

# %% [markdown]
# # **Updated Milestone 3**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from statsmodels.tsa.arima.model import ARIMA

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("azure_demand_feature_engineered.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df = df.sort_values("timestamp").reset_index(drop=True)

# %%
target = "usage_units"

features = df.drop(columns=["timestamp","usage_units"]).columns

X = df[features]
y = df[target]

# %%
split = int(len(df)*0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

# %%
rf = RandomForestRegressor(random_state=42)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

# %%
xgb = XGBRegressor(random_state=42)

xgb.fit(X_train, y_train)

xgb_pred = xgb.predict(X_test)

# %%
arima_model = ARIMA(y_train, order=(1,1,1))

arima_fit = arima_model.fit()

arima_pred = arima_fit.forecast(steps=len(y_test))

# %%
def evaluate(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    bias = np.mean(y_pred - y_true)
    return mae, rmse, bias

# %%
rf_mae, rf_rmse, rf_bias = evaluate(y_test, rf_pred)
xgb_mae, xgb_rmse, xgb_bias = evaluate(y_test, xgb_pred)
arima_mae, arima_rmse, arima_bias = evaluate(y_test, arima_pred)

baseline_results = pd.DataFrame({
    "Model":["Random Forest","XGBoost","ARIMA"],
    "MAE":[rf_mae,xgb_mae,arima_mae],
    "RMSE":[rf_rmse,xgb_rmse,arima_rmse],
    "Bias":[rf_bias,xgb_bias,arima_bias]
})

print("Baseline Results:\n", baseline_results)
# Out:
# Baseline Results:
#             Model          MAE         RMSE         Bias
# 0  Random Forest   189.575736   482.463609    14.891853
# 1        XGBoost   287.558726   546.874165    -3.892376
# 2          ARIMA  2321.856844  3041.260725 -1492.313408

# %%
from sklearn.model_selection import RandomizedSearchCV

rf_params = {
    "n_estimators":[200,300,400],
    "max_depth":[10,15,20,None],
    "min_samples_split":[2,5],
    "min_samples_leaf":[1,2]
}

rf_search = RandomizedSearchCV(
    RandomForestRegressor(random_state=42),
    rf_params,
    n_iter=10,
    cv=3,
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    random_state=42
)

rf_search.fit(X_train,y_train)

best_rf = rf_search.best_estimator_

rf_pred_tuned = best_rf.predict(X_test)

# %%
xgb_params = {
    "n_estimators":[300,400,500],
    "max_depth":[4,6,8],
    "learning_rate":[0.01,0.05,0.1],
    "subsample":[0.7,0.8,1],
    "colsample_bytree":[0.7,0.8,1]
}

xgb_search = RandomizedSearchCV(
    XGBRegressor(random_state=42),
    xgb_params,
    n_iter=10,
    cv=3,
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    random_state=42
)

xgb_search.fit(X_train,y_train)

best_xgb = xgb_search.best_estimator_

xgb_pred_tuned = best_xgb.predict(X_test)

# %%
import itertools

p = range(0,3)
d = range(0,2)
q = range(0,3)

pdq = list(itertools.product(p,d,q))

best_aic = float("inf")
best_order = None
best_model = None

for order in pdq:
    try:
        model = ARIMA(y_train, order=order)
        result = model.fit()

        if result.aic < best_aic:
            best_aic = result.aic
            best_order = order
            best_model = result

    except:
        continue

print("Best ARIMA:", best_order)

arima_pred_tuned = best_model.forecast(steps=len(y_test))
# Out:
# Best ARIMA: (1, 1, 1)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values,label="Actual")
plt.plot(rf_pred_tuned,label="Random Forest")
plt.plot(xgb_pred_tuned,label="XGBoost")
# plt.plot(arima_pred_tuned,label="ARIMA")
plt.legend()
plt.title("Backtesting: Actual vs Predictions")
plt.show()

# %%
rf_mae_tuned, rf_rmse_tuned, rf_bias_tuned = evaluate(y_test, rf_pred_tuned)
xgb_mae_tuned, xgb_rmse_tuned, xgb_bias_tuned = evaluate(y_test, xgb_pred_tuned)
arima_mae_tuned, arima_rmse_tuned, arima_bias_tuned = evaluate(y_test, arima_pred_tuned)

final_results = pd.DataFrame({
    "Model":["Random Forest (Tuned)","XGBoost (Tuned)","ARIMA (Tuned)", "Random Forest (Untuned)", "XGBoost (Untuned)", "ARIMA (Untuned)"],
    "MAE":[rf_mae_tuned,xgb_mae_tuned,arima_mae_tuned, rf_mae, xgb_mae, arima_mae],
    "RMSE":[rf_rmse_tuned,xgb_rmse_tuned,arima_rmse_tuned, rf_rmse, xgb_rmse, arima_rmse],
    "Bias":[rf_bias_tuned,xgb_bias_tuned,arima_bias_tuned, rf_bias, xgb_bias, arima_bias]
})

print("Final Results:\n", final_results)
best_model_name = final_results.sort_values("RMSE").iloc[0]["Model"]
print("Best Model:", best_model_name)
# Out:
# Final Results:
#                       Model          MAE         RMSE         Bias
# 0    Random Forest (Tuned)   183.279591   465.121813     7.922868
# 1          XGBoost (Tuned)   242.867429   542.580587     3.510416
# 2            ARIMA (Tuned)  2321.856844  3041.260725 -1492.313408
# 3  Random Forest (Untuned)   189.575736   482.463609    14.891853
# 4        XGBoost (Untuned)   287.558726   546.874165    -3.892376
# 5          ARIMA (Untuned)  2321.856844  3041.260725 -1492.313408
# Best Model: Random Forest (Tuned)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

# Plot MAE
plt.subplot(1, 3, 1)
sns.barplot(x='Model', y='MAE', data=final_results.sort_values('MAE'))
plt.title('Mean Absolute Error (MAE) Comparison')
plt.xticks(rotation=45, ha='right')
plt.ylabel('MAE')

# Plot RMSE
plt.subplot(1, 3, 2)
sns.barplot(x='Model', y='RMSE', data=final_results.sort_values('RMSE'))
plt.title('Root Mean Squared Error (RMSE) Comparison')
plt.xticks(rotation=45, ha='right')
plt.ylabel('RMSE')

# Plot Bias
plt.subplot(1, 3, 3)
sns.barplot(x='Model', y='Bias', data=final_results.sort_values('Bias'))
plt.title('Forecast Bias Comparison')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Bias')

plt.tight_layout()
plt.show()

# %%
import joblib
joblib.dump(best_rf, "rf_model.pkl")
print("Model saved!")
# Out:
# Model saved!

# %%
from google.colab import files
files.download("rf_model.pkl")
